# %% [markdown]
# This notebook aims to create a function that convert user inputs to a dataframe to make a predict.
#
# Now, it is possible:
# - to have up to 17 parameters as an input (instead of only 3 before)
# - to have missing inputs

# %% [markdown]
# The possible parameters are:
# - loan_limit,
# - Gender,
# - open_credit,
# - business_or_commercial,
# - loan_amount,
# - term,
# - interest_only,
# - lump_sum_payment,
# - property_value,
# - construction_type,
# - occupancy_type,
# - Secured_by,
# - total_units,
# - income,
# - age,
# - Region,
# - Security_Type

# %% [markdown]
# # Import

# %%
# General
import pickle

# Analysis
import pandas as pd

# Visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# Machine learning
from sklearn.linear_model import LogisticRegression


# Autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Loading the dataset and create a Dataframe

# %% [markdown]
# ## Loading the data

# %%
ROOT_PATH = pathlib.Path().resolve().parent # Get the parent directory of the current working directory
raw_data_path = os.path.join(ROOT_PATH, 'raw_data', 'Loan_Default.csv')

# Printing raw_data_path
print('Raw_data_path: ', raw_data_path)
# Out:
# Raw_data_path:  /home/nicolas/code/YannAll/automated_loan_review_project/raw_data/Loan_Default.csv

# %% [markdown]
# ## Creating the DataFrame

# %%
# Convert the Loan_Default.file to a DataFrame
data_raw = pd.read_csv(raw_data_path)
data_raw.head(3)
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  \
# 0           p1                l1        nopc                  nob/c
# 1           p1                l1        nopc                    b/c
# 2           p1                l1        nopc                  nob/c
#
#    loan_amount  rate_of_interest  Interest_rate_spread  Upfront_charges  \
# 0       116500               NaN                   NaN              NaN
# 1       206500               NaN                   NaN              NaN
# 2       406500              4.56                   0.2            595.0
#
#     term Neg_ammortization interest_only lump_sum_payment  property_value  \
# 0  360.0           not_neg       not_int         not_lpsm        118000.0
# 1  360.0           not_neg       not_int             lpsm             NaN
# 2  360.0           neg_amm       not_int         not_lpsm        508000.0
#
#   construction_type occupancy_type Secured_by total_units  income credit_type  \
# 0                sb             pr       home          1U  1740.0         EXP
# 1                sb             pr       home          1U  4980.0        EQUI
# 2                sb             pr       home          1U  9480.0         EXP
#
#    Credit_Score co-applicant_credit_type    age submission_of_application  \
# 0           758                      CIB  25-34                   to_inst
# 1           552                      EXP  55-64                   to_inst
# 2           834                      CIB  35-44                   to_inst
#
#          LTV Region Security_Type  Status  dtir1
# 0  98.728814  south        direct       1   45.0
# 1        NaN  North        direct       1    NaN
# 2  80.019685  south        direct       0   46.0

# %% [markdown]
# # Creating, fitting and saving a preprocessor for input data

# %%
# Numerical transformer
num_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy="median"))
])

# Categorical transformer
cat_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy="most_frequent"))
])

# Parallelize "num_transformer" and "cat_transfomer"
preprocessor = ColumnTransformer([
    ('num_transformer', num_transformer, num_col),
    ('cat_transformer', cat_transformer, cat_col)
])

preprocessor
# Out:
# ColumnTransformer(transformers=[('num_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f81564435b0>),
#                                 ('cat_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f81553b6fb0>)])

# %%
# Fit the preprocessor to the raw data dataframe
preprocessor.fit(data_raw)
# Out:
# ColumnTransformer(transformers=[('num_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f81564435b0>),
#                                 ('cat_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f81553b6fb0>)])

# %%
# Save the fitted preprocessor
with open('../models/preprocessor_fitted_input.pkl', 'wb') as file:
    pickle.dump(preprocessor, file)

# %% [markdown]
# # Creating a base input dataframe

# %% [markdown]
# ## Loading the fitted preprocessor

# %%
# Load the model from the fitted preprocessor pickle file
ROOT_PATH = pathlib.Path().resolve().parent # Get the parent directory of the current working directory
preprocessor_input_path = os.path.join(ROOT_PATH, 'models', 'preprocessor_fitted_input.pkl')
print(f"Path of the preprocessor.pkl:\n{preprocessor_input_path}\n")
with open(preprocessor_input_path, 'rb') as file:
    preprocessor = pickle.load(file)
# Out:
# Path of the preprocessor.pkl:
# /home/nicolas/code/YannAll/automated_loan_review_project/models/preprocessor_fitted_input.pkl

# %% [markdown]
# ## Imputing the dataframe

# %%
# Creating a NaN dataframe ready to be imputed
df_nan = pd.DataFrame(np.nan, index = np.arange(1), columns = data_raw.columns)
df_nan
# Out:
#    ID  year  loan_limit  Gender  approv_in_adv  loan_type  loan_purpose  \
# 0 NaN   NaN         NaN     NaN            NaN        NaN           NaN
#
#    Credit_Worthiness  open_credit  business_or_commercial  loan_amount  \
# 0                NaN          NaN                     NaN          NaN
#
#    rate_of_interest  Interest_rate_spread  Upfront_charges  term  \
# 0               NaN                   NaN              NaN   NaN
#
#    Neg_ammortization  interest_only  lump_sum_payment  property_value  \
# 0                NaN            NaN               NaN             NaN
#
#    construction_type  occupancy_type  Secured_by  total_units  income  \
# 0                NaN             NaN         NaN          NaN     NaN
#
#    credit_type  Credit_Score  co-applicant_credit_type  age  \
# 0          NaN           NaN                       NaN  NaN
#
#    submission_of_application  LTV  Region  Security_Type  Status  dtir1
# 0                        NaN  NaN     NaN            NaN     NaN    NaN

# %%
# Impute the Nan DF with value
df_base = preprocessor.transform(df_nan)
df_base
# Out:
# array([[99224.5, 2019.0, 296500.0, 3.99, 0.3904, 2596.45, 360.0,
#         418000.0, 5760.0, 699.0, 75.13586957, 0.0, 39.0, 'cf', 'Male',
#         'nopre', 'type1', 'p3', 'l1', 'nopc', 'nob/c', 'not_neg',
#         'not_int', 'not_lpsm', 'sb', 'pr', 'home', '1U', 'CIB', 'CIB',
#         '45-54', 'to_inst', 'North', 'direct']], dtype=object)

# %%
# Impute the Nan with the preprocessor
df_base = pd.DataFrame(preprocessor.transform(df_nan), index=np.arange(1), columns=preprocessor.get_feature_names_out())
df_base
# Out:
#   num_transformer__ID num_transformer__year num_transformer__loan_amount  \
# 0             99224.5                2019.0                     296500.0
#
#   num_transformer__rate_of_interest num_transformer__Interest_rate_spread  \
# 0                              3.99                                0.3904
#
#   num_transformer__Upfront_charges num_transformer__term  \
# 0                          2596.45                 360.0
#
#   num_transformer__property_value num_transformer__income  \
# 0                        418000.0                  5760.0
#
#   num_transformer__Credit_Score num_transformer__LTV num_transformer__Status  \
# 0                         699.0             75.13587                     0.0
#
#   num_transformer__dtir1 cat_transformer__loan_limit cat_transformer__Gender  \
# 0                   39.0                          cf                    Male
#
#   cat_transformer__approv_in_adv cat_transformer__loan_type  \
# 0                          nopre                      type1
#
#   cat_transformer__loan_purpose cat_transformer__Credit_Worthiness  \
# 0                            p3                                 l1
#
#   cat_transformer__open_credit cat_transformer__business_or_commercial  \
# 0                         nopc                                   nob/c
#
#   cat_transformer__Neg_ammortization cat_transformer__interest_only  \
# 0                            not_neg                        not_int
#
#   cat_transformer__lump_sum_payment cat_transformer__construction_type  \
# 0                          not_lpsm                                 sb
#
#   cat_transformer__occupancy_type cat_transformer__Secured_by  \
# 0                              pr                        home
#
#   cat_transformer__total_units cat_transformer__credit_type  \
# 0                           1U                          CIB
#
#   cat_transformer__co-applicant_credit_type cat_transformer__age  \
# 0                                       CIB                45-54
#
#   cat_transformer__submission_of_application cat_transformer__Region  \
# 0                                    to_inst                   North
#
#   cat_transformer__Security_Type
# 0                         direct

# %%
# Remove the first 17 characters from each column name
df_base.columns = df_base.columns.str.slice(17)
df_base
# Out:
#         ID    year loan_amount rate_of_interest Interest_rate_spread  \
# 0  99224.5  2019.0    296500.0             3.99               0.3904
#
#   Upfront_charges   term property_value  income Credit_Score       LTV Status  \
# 0         2596.45  360.0       418000.0  5760.0        699.0  75.13587    0.0
#
#   dtir1 loan_limit Gender approv_in_adv loan_type loan_purpose  \
# 0  39.0         cf   Male         nopre     type1           p3
#
#   Credit_Worthiness open_credit business_or_commercial Neg_ammortization  \
# 0                l1        nopc                  nob/c           not_neg
#
#   interest_only lump_sum_payment construction_type occupancy_type Secured_by  \
# 0       not_int         not_lpsm                sb             pr       home
#
#   total_units credit_type co-applicant_credit_type    age  \
# 0          1U         CIB                      CIB  45-54
#
#   submission_of_application Region Security_Type
# 0                   to_inst  North        direct

# %% [markdown]
# ## Overwrite user's value in the DF

# %%
loan_limit=None
income=None
age=32

# %%
# Creating a dict from the inputs
dict = {
    'loan_limit': loan_limit,
    'income': income,
    'age': age
}
dict
# Out:
# {'loan_limit': None, 'income': None, 'age': 32}

# %%
# Creating a Dataframe from the dict
df_input = pd.DataFrame(dict, index = np.arange(1))
df_input
# Out:
#   loan_limit income  age
# 0       None   None   32

# %%
# Get columns names
column_names = list(df_input.columns)
column_names
# Out:
# ['loan_limit', 'income', 'age']

# %%
# Replace df_base values by inputs values if not None
for column_name in column_names:
    if df_input.at[0, column_name] is not None:
        df_base.at[0, column_name] = df_input.loc[0, column_name]

df_base
# Out:
#         ID    year loan_amount rate_of_interest Interest_rate_spread  \
# 0  99224.5  2019.0    296500.0             3.99               0.3904
#
#   Upfront_charges   term property_value  income Credit_Score       LTV Status  \
# 0         2596.45  360.0       418000.0  5760.0        699.0  75.13587    0.0
#
#   dtir1 loan_limit Gender approv_in_adv loan_type loan_purpose  \
# 0  39.0         cf   Male         nopre     type1           p3
#
#   Credit_Worthiness open_credit business_or_commercial Neg_ammortization  \
# 0                l1        nopc                  nob/c           not_neg
#
#   interest_only lump_sum_payment construction_type occupancy_type Secured_by  \
# 0       not_int         not_lpsm                sb             pr       home
#
#   total_units credit_type co-applicant_credit_type age  \
# 0          1U         CIB                      CIB  32
#
#   submission_of_application Region Security_Type
# 0                   to_inst  North        direct

# %% [markdown]
# # Creating a base input dataframe in a function

# %%
def create_df_from_inputs(loan_limit=None, Gender=None, open_credit=None,
                     business_or_commercial=None, loan_amount=None,
                     term=None, interest_only=None, lump_sum_payment=None,
                     property_value=None, construction_type=None, occupancy_type=None,
                     Secured_by=None, total_units=None, income=None, age=None, Region=None,
                     Security_Type=None):

    # Load the model from the fitted preprocessor pickle file
    ROOT_PATH = pathlib.Path().resolve().parent # Get the parent directory of the current working directory
    preprocessor_input_path = os.path.join(ROOT_PATH, 'models', 'preprocessor_fitted_input.pkl')
    # print(f"Path of the preprocessor.pkl:\n{preprocessor_input_path}\n")
    with open(preprocessor_input_path, 'rb') as file:
        preprocessor = pickle.load(file)

    columns_names = [column_name[17:] for column_name in preprocessor.get_feature_names_out()]

    # Creating a NaN dataframe ready to be imputed
    df_nan = pd.DataFrame(np.nan, index = np.arange(1), columns =columns_names)

    # Impute the Nan with the preprocessor
    df_base = pd.DataFrame(preprocessor.transform(df_nan), index=np.arange(1), columns=preprocessor.get_feature_names_out())

    # Remove the first 17 characters from each column name
    df_base.columns = df_base.columns.str.slice(17)

    # Creating a dict from the inputs
    dict = {
        'loan_limit': loan_limit,
        'Gender': Gender,
        'open_credit': open_credit,
        'business_or_commercial': business_or_commercial,
        'loan_amount': loan_amount,
        'term': term,
        'interest_only': interest_only,
        'lump_sum_payment': lump_sum_payment,
        'property_value': property_value,
        'construction_type': construction_type,
        'occupancy_type': occupancy_type,
        'Secured_by': Secured_by,
        'total_units': total_units,
        'income': income,
        'age': age,
        'Region': Region,
        'Security_Type': Security_Type
    }

    # Creating a Dataframe from the dict
    df_input = pd.DataFrame(dict, index = np.arange(1))

    # Get columns names

    column_names = list(df_input.columns)

    # Replace df_base values by inputs values if not None
    for column_name in column_names:
        if df_input.at[0, column_name] is not None:
            df_base.at[0, column_name] = df_input.loc[0, column_name]

    return df_base

# %%
# Checking the function
pd.set_option('display.max_columns', None)
df_user_input_consolidated = create_df_from_inputs(loan_limit="azerty", age="45-54", income=34545)
df_user_input_consolidated
# Out:
#         ID    year loan_amount rate_of_interest Interest_rate_spread  \
# 0  99224.5  2019.0    296500.0             3.99               0.3904
#
#   Upfront_charges   term property_value income Credit_Score       LTV Status  \
# 0         2596.45  360.0       418000.0  34545        699.0  75.13587    0.0
#
#   dtir1 loan_limit Gender approv_in_adv loan_type loan_purpose  \
# 0  39.0     azerty   Male         nopre     type1           p3
#
#   Credit_Worthiness open_credit business_or_commercial Neg_ammortization  \
# 0                l1        nopc                  nob/c           not_neg
#
#   interest_only lump_sum_payment construction_type occupancy_type Secured_by  \
# 0       not_int         not_lpsm                sb             pr       home
#
#   total_units credit_type co-applicant_credit_type    age  \
# 0          1U         CIB                      CIB  45-54
#
#   submission_of_application Region Security_Type
# 0                   to_inst  North        direct

# %% [markdown]
# # END OF THE NOTEBOOK
